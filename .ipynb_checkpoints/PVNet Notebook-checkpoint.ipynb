# %%
import os

import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch
import torchvision
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

from PIL import Image

import data
import pvnet_utils

ROOT_DIR = "dataset/LINEMOD"

# %matplotlib inline

# %% [markdown]
# ### Split files into test and train split

# %%
X_train, X_test, y_train, y_test = pvnet_utils.get_test_train_split(ROOT_DIR,['duck', 'cat', 'lamp'], 
                                                                    test_size=0.33, 
                                                                    random_state=2, 
                                                                    shuffle=True)

X = X_train[:1, :]
y = y_train[:1]

print(X)
print(y)
# Out:
# [['dataset/LINEMOD/cat/JPEGImages/001136.jpg'
#   'dataset/LINEMOD/cat/mask/1136.png'
#   'dataset/LINEMOD/cat/labels/001136.txt']]
# ['cat']

# %% [markdown]
# ### Create Dataset and Dataloader and visualize some batches

# %%
dataset = data.LineModReader((X_train, y_train))
dataloader = DataLoader(dataset, batch_size=8, shuffle=True)

# %% [markdown]
# ### Visualize a batch

# %%
dataset.show_batch(3)
