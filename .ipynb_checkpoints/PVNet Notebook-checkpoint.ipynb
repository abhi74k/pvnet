# %%
import os
from importlib import reload

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split

import torch
import torchvision
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as T

from PIL import Image

import data
import models
import pvnet_utils
reload(pvnet_utils)

ROOT_DIR = "dataset/LINEMOD"
FOLDERNAME = 'cs231a/pvnet/'

# %matplotlib inline

# %% [markdown]
# ### Split files into test and train split

# %%
reload(data)
X_train, X_test, y_train, y_test = pvnet_utils.get_test_train_split(ROOT_DIR,['duck', 'cat', 'lamp'], 
                                                                    test_size=0.33, 
                                                                    random_state=2, 
                                                                    shuffle=True)

X = X_train[:1, :]
y = y_train[:1]


print(X)
print(y)

print("Test data set")

print(X_test[0, :])
print(y_test[0])
# Out:
# [['dataset/LINEMOD/cat/JPEGImages/000208.jpg'
#   'dataset/LINEMOD/cat/mask/0208.png'
#   'dataset/LINEMOD/cat/labels/000208.txt']]
# ['cat']
# Test data set
# ['dataset/LINEMOD/duck/JPEGImages/000521.jpg'
#  'dataset/LINEMOD/duck/mask/0521.png'
#  'dataset/LINEMOD/duck/labels/000521.txt']
# duck

# %% [markdown]
# ### Make a prediction

# %%
reload(pvnet_utils)

def create_model_with_weights(model_weights_path, device = 'infer'):
    #Create model
    pvnet = models.PvNet(
        num_classes = 13,
        num_keypoints = 9,
        norm_layer = None,
        output_class = True,
        output_vector = True)
    
    optimizer = torch.optim.Adam(pvnet.parameters(), lr=0)
    
    if device == 'infer':
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    else:
        device = torch.device("cuda:0" if device == "cuda" else "cpu")
        
    pvnet_utils.load_model(pvnet, optimizer, model_weights_path, device)
    
    print('Done loading model weights')
    
    return pvnet

def make_prediction(pvnet, test_image, test_class, display_class=True):
    
    # Image to tensor
    Img2Tensor = T.ToTensor()
    test_image = torch.unsqueeze(Img2Tensor(test_image), 0)
    
    # Make a prediction
    pred = pvnet(test_image)
    pred_class = pred['class']
    pred_vectors = pred['vector']
    
    # Render the prediction
    if display_class:
        classviz = torch.topk(pred_class[0], 1, dim=0)[1] * 12
        plt.imshow(dataset.tensorToImage(classviz.type(torch.FloatTensor)),cmap='gray')
        plt.show()

     # Load the 3D points for the class
    print(test_class)
    points3d = pvnet_utils.get_3d_points(test_class)
    
     # Segmentation mask and unit vectors to 2D points using RANSAC
    points2d = np.zeros((points3d.shape[0], 2)) # Replace this with keypoint voting
    
     # PnP to compute R, t from 
    _, R, t = pvnet_utils.solve_pnp(points3d, points2d)

test_image_path = X_test[0, :][0]
test_image = Image.open(test_image_path)
test_class = y_test[0]

pvnet = create_model_with_weights('checkpoints/ckpt_0.pth', device='cpu')
make_prediction(pvnet, test_image, test_class)
# Out:
# Done loading model weights
# duck
# 3D points path:dataset/LINEMOD/duck/corners.txt

# %% [markdown]
# ### Create Dataset and Dataloader and visualize some batches

# %% [markdown]
# ### Visualize a batch

# %%
reload(data)
reload(pvnet_utils)
dataset = data.LineModReader((X_train, y_train))
dataloader = DataLoader(dataset, batch_size=8, shuffle=True)
dataset.show_batch(3)

print(dataset[0]['class_label'])
print(dataset[0]['class_mask'].max())
# Out:
# tensor(4)
# tensor(1)

# %%
from torchsummary import summary
reload(models)


# Test model
newmodel = models.PvNet(
    num_classes = 12,
    num_keypoints = 9,
    norm_layer = None,
    output_class = True,
    output_vector = False,
    pretrained = True
)
# summary(newmodel,(3,640,480))

# Outputs
print(torch.unsqueeze(dataset[0]['img'],0).size())

class_out = (newmodel(torch.unsqueeze(dataset[0]['img'],0)))['class'][0]
print(class_out.size())

# Get top class, scale by 12 for vis diff
classviz = torch.topk(class_out, 1, dim=0)[1] * 12
print(classviz.size())

plt.imshow(dataset.tensorToImage(classviz.type(torch.FloatTensor)),cmap='gray')
plt.show()


del newmodel
del dataset

# newmodel(dataset)
# Out:
# torch.Size([1, 3, 480, 640])
# C:\Users\chasi\ana\anaconda3\lib\site-packages\torch\nn\functional.py:3631: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# torch.Size([13, 480, 640])
# torch.Size([1, 480, 640])

# %% [markdown]
# ### Starting Tensorboard

# %%
# !pip install tensorboard
# %reload_ext tensorboard

#%tensorboard --logdir "/content/drive/MyDrive/$FOLDERNAME/runs" --port 6009
# %tensorboard --logdir "./runs" --port 6011
# Out:
# Requirement already satisfied: tensorboard in c:\python38\lib\site-packages (2.8.0)
# Requirement already satisfied: grpcio>=1.24.3 in c:\python38\lib\site-packages (from tensorboard) (1.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\python38\lib\site-packages (from tensorboard) (2.6.0)
# Requirement already satisfied: protobuf>=3.6.0 in c:\python38\lib\site-packages (from tensorboard) (3.19.4)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\python38\lib\site-packages (from tensorboard) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\python38\lib\site-packages (from tensorboard) (3.3.6)
# Requirement already satisfied: absl-py>=0.4 in c:\python38\lib\site-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\python38\lib\site-packages (from tensorboard) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\python38\lib\site-packages (from tensorboard) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\python38\lib\site-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in c:\python38\lib\site-packages (from tensorboard) (0.37.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\python38\lib\site-packages (from tensorboard) (1.22.2)
# Requirement already satisfied: setuptools>=41.0.0 in c:\python38\lib\site-packages (from tensorboard) (41.2.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\python38\lib\site-packages (from tensorboard) (0.4.6)
# Requirement already satisfied: six>=1.5.2 in c:\python38\lib\site-packages (from grpcio>=1.24.3->tensorboard) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\python38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\python38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\python38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (5.0.0)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in c:\python38\lib\site-packages (from markdown>=2.6.8->tensorboard) (4.11.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python38\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\python38\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python38\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\python38\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2.0.12)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\python38\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\python38\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in c:\python38\lib\site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard) (3.7.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\python38\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.2.0)
# WARNING: You are using pip version 19.2.3, however version 22.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Reusing TensorBoard on port 6011 (pid 9820), started 6:25:09 ago. (Use '!kill 9820' to kill it.)
#       <iframe id="tensorboard-frame-d832af48a975c990" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d832af48a975c990");
#           const url = new URL("/", window.location);
#           const port = 6011;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Model Training

# %%
reload(data)
reload(models)

x_train, x_test, y_train, y_test = pvnet_utils.get_test_train_split(ROOT_DIR, ['duck', 'cat', 'lamp'], test_size=0.2, shuffle=False)

train_dataset = data.LineModReader((x_train, y_train))
test_dataset = data.LineModReader((x_test, y_test))

train_dataloader = DataLoader(train_dataset, batch_size=8, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=8, shuffle=True)

class_model = models.PvNet(
    num_classes = 13,
    num_keypoints = 9,
    norm_layer = None,
    output_class = True,
    output_vector = True,
    pretrained = True
)

# %%
import training
reload(training)
reload(pvnet_utils)

training.train(epochs= 1,
    train_data_loader = train_dataloader,
    test_data_loader = train_dataloader,
    device = 'cpu',
    checkpoint_batch_freq=100,
    #checkpoint_path='checkpoints/ckpt_0.pth',
    model = class_model)
# Out:
#   0%|                                                                                       | 0/366 [00:00<?, ?batch/s]
# Resuming from: epoch #1
# Epoch 2/2:   0%|                                                                            | 0/366 [00:38<?, ?batch/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-3b0caafa34e6> in <module>
#       3 reload(pvnet_utils)
#       4
# ----> 5 training.train(epochs= 2,
#       6     train_data_loader = train_dataloader,
#       7     test_data_loader = train_dataloader,
#
# ~\PycharmProjects\pvnet\training.py in train(epochs, train_data_loader, test_data_loader, lr, save, theta, device, pretrained, checkpoint_path, checkpoint_batch_freq, model, start_epoch)
#      86                 running_loss_for_epoch += net_loss
#      87
# ---> 88                 accuracy = pvnet_utils.calculate_accuracy(preds['class'], batch['class_mask'], batch['class_label'],
#      89                                                           model.num_classes)
#      90
#
# ~\PycharmProjects\pvnet\pvnet_utils.py in calculate_accuracy(class_preds, class_mask_gt, class_label_gt, num_classes)
#     147
#     148     # (N, C, H, W) -> (N, H, W)
# --> 149     img_classes_pred = torch.argmax(class_preds.cpu(), axis=1)
#     150
#     151     num_correct_pred = (img_classes_pred == img_classes_gt).sum().item()
#
# KeyboardInterrupt:
